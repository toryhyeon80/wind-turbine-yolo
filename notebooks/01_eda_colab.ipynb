# %% [markdown]
# # 01 · EDA (Colab)
#
# **역할:** Data Engineer
# **로컬 동일:** `python3 eda.py`

# %%
# Colab: Runtime → GPU 선택 (EDA는 CPU만으로도 가능)
REPO = "https://github.com/toryhyeon80/wind-turbine-yolo.git"
# !git clone {REPO} wind-turbine-yolo 2>/dev/null || (cd wind-turbine-yolo && git pull)
# %cd wind-turbine-yolo
# !pip install -q -r requirements.txt

# %%
# data/ 가 없으면 split_data.py 는 로컬/팀 Data Engineer 가 준비한 뒤 실행
# EDA만: runs/eda 가 있으면 그래프 확인, 없으면 eda.py 실행
# !python3 eda.py
# !python3 update_report.py

# %%
from IPython.display import Image, display
from pathlib import Path
for p in sorted(Path("runs/eda").glob("*.png")):
    print(p.name)
    display(Image(filename=str(p)))
