# %% [markdown]
# # 02 · Train (Colab GPU)
#
# **역할:** AI Engineer
# **설정:** `configs/train_colab.yaml` (`device: 0` CUDA)
#
# Mac 로컬: `python3 train.py` → `configs/train.yaml` (`device: mps`)

# %%
# !nvidia-smi
REPO = "https://github.com/toryhyeon80/wind-turbine-yolo.git"
# !git clone {REPO} wind-turbine-yolo 2>/dev/null || (cd wind-turbine-yolo && git pull)
# %cd wind-turbine-yolo
# !pip install -q -r requirements.txt

# %%
# (선택) Google Drive에 runs/ 백업
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# 본학습 — Colab GPU
# !python3 train.py --config configs/train_colab.yaml --no-report

# %%
from IPython.display import Image, display
from pathlib import Path
p = Path("runs/detect/train_colab/results.png")
if p.exists():
    display(Image(filename=str(p)))
else:
    print("학습 완료 후 results.png 확인")
